# %% [markdown]
# <a href="https://colab.research.google.com/github/Emma922/Olist-Project/blob/main/olist_eda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exploratory Data Analysis (Olist Db)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ##Import and previewing all the datasets

# %%
from google.colab import files
uploaded = files.upload()

import pandas as pd
import io

# Use only the filename as key, NOT the full local path
df_geolocation = pd.read_csv(io.BytesIO(uploaded['geolocation_olist_public_dataset (5).csv']))
df_geolocation.head()
# Out:
#      <input type="file" id="files-ef0ca1c9-2d6b-49d5-946e-587f41a210c1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ef0ca1c9-2d6b-49d5-946e-587f41a210c1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
uploaded = files.upload()

import pandas as pd
import io

# Use only the filename as key, NOT the full local path
df_classified = pd.read_csv(io.BytesIO(uploaded['olist_classified_public_dataset (1).csv']))
df_classified.head()
# Out:
#      <input type="file" id="files-0a9a0867-8ace-4eca-8bbf-9fbf73262e43" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0a9a0867-8ace-4eca-8bbf-9fbf73262e43">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
uploaded = files.upload()

import pandas as pd
import io

# Use only the filename as key, NOT the full local path
df_public_dataset = pd.read_csv(io.BytesIO(uploaded['olist_public_dataset_v2 (1).csv']))
df_public_dataset.head()
# Out:
#      <input type="file" id="files-6890eefd-c8ef-4e2b-a3ca-0e6eef7edcae" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6890eefd-c8ef-4e2b-a3ca-0e6eef7edcae">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
uploaded = files.upload()

import pandas as pd
import io

# Use only the filename as key, NOT the full local path
df_public_dataset_customers = pd.read_csv(io.BytesIO(uploaded['olist_public_dataset_v2_customers (1).csv']))
df_public_dataset_customers.head()
# Out:
#      <input type="file" id="files-9dffd16f-f89f-4607-9333-e0a3df5ed2f2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9dffd16f-f89f-4607-9333-e0a3df5ed2f2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
uploaded = files.upload()

import pandas as pd
import io

# Use only the filename as key, NOT the full local path
df_payments = pd.read_csv(io.BytesIO(uploaded['payments_olist_public_dataset (1).csv']))
df_payments.head()
# Out:
#      <input type="file" id="files-65cc26b5-13a7-47cf-a726-4c741ed1af11" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-65cc26b5-13a7-47cf-a726-4c741ed1af11">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
uploaded = files.upload()

import pandas as pd
import io

# Use only the filename as key, NOT the full local path
df_product_measures = pd.read_csv(io.BytesIO(uploaded['product_measures_olist_public_dataset_ (1).csv']))
df_product_measures.head()
# Out:
#      <input type="file" id="files-f96e027b-6bc5-4387-aee5-18bd96500d02" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f96e027b-6bc5-4387-aee5-18bd96500d02">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
uploaded = files.upload()

import pandas as pd
import io

# Use only the filename as key, NOT the full local path
df_sellers = pd.read_csv(io.BytesIO(uploaded['sellers_olist_public_dataset_ (1).csv']))
df_sellers.head()
# Out:
#      <input type="file" id="files-ee5db1c5-495a-4e9a-8447-83c8fce00438" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ee5db1c5-495a-4e9a-8447-83c8fce00438">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
uploaded = files.upload()

import pandas as pd
import io

# Use only the filename as key, NOT the full local path
df_translation = pd.read_csv(io.BytesIO(uploaded['product_category_name_translation (6).csv']))
df_translation.head()
# Out:
#      <input type="file" id="files-af8e9909-631e-4ce2-b99a-7d227432cb9b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-af8e9909-631e-4ce2-b99a-7d227432cb9b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ##Understanding the structure

# %%
dfs = {
    'classified': df_classified,
    'location': df_geolocation,
    'payments': df_payments,
    'product_measures': df_product_measures,
    'public_data': df_public_dataset,
    'customers': df_public_dataset_customers,
    'sellers': df_sellers,
    'translation': df_translation

}
for name, df in dfs.items():
    print(f"\nInfo for {name}:")
    df.info()
# Out:
# Info for classified:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3584 entries, 0 to 3583
# Data columns (total 34 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Unnamed: 0                     3584 non-null   int64
#  1   id                             3584 non-null   int64
#  2   order_status                   3584 non-null   object
#  3   order_products_value           3584 non-null   float64
#  4   order_freight_value            3584 non-null   float64
#  5   order_items_qty                3584 non-null   int64
#  6   order_sellers_qty              3584 non-null   int64
#  7   order_purchase_timestamp       3584 non-null   object
#  8   order_aproved_at               3584 non-null   object
#  9   order_estimated_delivery_date  3584 non-null   object
#  10  order_delivered_customer_date  3467 non-null   object
#  11  customer_city                  3584 non-null   object
# ...

# %% [markdown]
# ##Getting descriptive statistics

# %%
dfs = {
    'classified': df_classified,
    'location': df_geolocation,
    'payments': df_payments,
    'product_measures': df_product_measures,
    'public_data': df_public_dataset,
    'customers': df_public_dataset_customers,
    'sellers': df_sellers,
    'translation': df_translation

}
for name, df in dfs.items():
    print(f"\nDescription for {name}:")
    print(df.describe(include='all'))
# Out:
# Description for classified:
#         Unnamed: 0          id order_status  order_products_value  \
# count   3584.00000  3584.00000         3584            3584.00000
# unique         NaN         NaN            5                   NaN
# top            NaN         NaN    delivered                   NaN
# freq           NaN         NaN         3467                   NaN
# mean    1791.50000  1792.50000          NaN             133.24183
# std     1034.75601  1034.75601          NaN             210.21544
# min        0.00000     1.00000          NaN               3.50000
# 25%      895.75000   896.75000          NaN              48.00000
# 50%     1791.50000  1792.50000          NaN              79.99000
# 75%     2687.25000  2688.25000          NaN             146.99000
# max     3583.00000  3584.00000          NaN            4850.00000
#
#         order_freight_value  order_items_qty  order_sellers_qty  \
# count           3584.000000      3584.000000        3584.000000
# ...

# %% [markdown]
# ##Looking for missing values

# %%
dfs = {
    'classified': df_classified,
    'location': df_geolocation,
    'payments': df_payments,
    'product_measures': df_product_measures,
    'public_data': df_public_dataset,
    'customers': df_public_dataset_customers,
    'sellers': df_sellers,
    'translation': df_translation
}

for name, df in dfs.items():
    print(f"\nNull count for {name}:")
    print(df.isnull().sum())
# Out:
# Null count for classified:
# Unnamed: 0                          0
# id                                  0
# order_status                        0
# order_products_value                0
# order_freight_value                 0
# order_items_qty                     0
# order_sellers_qty                   0
# order_purchase_timestamp            0
# order_aproved_at                    0
# order_estimated_delivery_date       0
# order_delivered_customer_date     117
# customer_city                       0
# customer_state                      0
# customer_zip_code_prefix            0
# product_category_name               0
# product_name_lenght                 0
# product_description_lenght          0
# product_photos_qty                  0
# review_score                        0
# review_comment_title             3584
# review_comment_message              0
# review_creation_date                0
# review_answer_timestamp             0
# votes_before_estimate               0
# ...

# %% [markdown]
# ## Unique values

# %%
dfs = {
    'classified': df_classified,
    'location': df_geolocation,
    'payments': df_payments,
    'product_measures': df_product_measures,
    'public_data': df_public_dataset,
    'customers': df_public_dataset_customers,
    'sellers': df_sellers,
    'translation': df_translation
}

for name, df in dfs.items():
    print(f"\nUnique value counts for {name}:")
    print(df.nunique())
# Out:
# Unique value counts for classified:
# Unnamed: 0                       3584
# id                               3584
# order_status                        5
# order_products_value             1092
# order_freight_value              1597
# order_items_qty                     7
# order_sellers_qty                  10
# order_purchase_timestamp         3177
# order_aproved_at                 3204
# order_estimated_delivery_date     257
# order_delivered_customer_date    3090
# customer_city                     897
# customer_state                     26
# customer_zip_code_prefix          684
# product_category_name              60
# product_name_lenght                55
# product_description_lenght       1243
# product_photos_qty                 14
# review_score                        5
# review_comment_title                0
# review_comment_message           2812
# review_creation_date              319
# review_answer_timestamp          3114
# votes_before_estimate               4
# ...

# %% [markdown]
# ##Duplicate values

# %%
dfs = {
    'classified': df_classified,
    'location': df_geolocation,
    'payments': df_payments,
    'product_measures': df_product_measures,
    'public_data': df_public_dataset,
    'customers': df_public_dataset_customers,
    'sellers': df_sellers,
    'translation': df_translation
}

for name, df in dfs.items():
    print(f"\nDuplicate rows for {name}:")
    duplicates = df[df.duplicated()]
    if duplicates.empty:
        print("No duplicate rows found.")
    else:
        print(duplicates)
# Out:
# Duplicate rows for classified:
# No duplicate rows found.
#
# Duplicate rows for location:
#         zip_code_prefix            city state        lat        lng
# 23                   10       sao paulo    sp -23.546081 -46.644820
# 31                   10       sao paulo    sp -23.546081 -46.644820
# 42                   10       sao paulo    sp -23.540984 -46.642569
# 43                   10       sao paulo    sp -23.547807 -46.636122
# 44                   10       sao paulo    sp -23.538015 -46.631947
# ...                 ...             ...   ...        ...        ...
# 322999              999         estacao    rs -27.915710 -52.260629
# 323006              999  getulio vargas    rs -27.883268 -52.231932
# 323008              999  getulio vargas    rs -27.877125 -52.224882
# 323010              999        tapejara    rs -28.065501 -52.005870
# 323012              999        tapejara    rs -28.071667 -52.014481
#
# [47162 rows x 5 columns]
#
# Duplicate rows for payments:
# ...

# %% [markdown]
# ## Explore max values

# %%
display(df_public_dataset.sort_values(by= 'order_products_value',ascending=False).head())
display(df_payments.sort_values(by= 'value',ascending=False).head())
display(df_payments.sort_values(by= 'installments',ascending=False).head())
display(df_classified.sort_values(by= 'order_items_qty',ascending=False).head())
display(df_public_dataset.sort_values(by= 'order_freight_value',ascending=False).head())
# Out:
#                                order_id order_status  order_products_value  \
# 66418  03caa2c082116e1d31e67e9ae3700499    delivered               13440.0
# 69811  453988a33cf7b5cb5ce32385e9ecfcdc    delivered                9798.0
# 53594  20926be916c5a88fd0554fc7dbf62e37    delivered                8250.0
# 41833  736e1922ae60d0d6a89247b851902527    delivered                7160.0
# 35123  0812eb902a67711a1cb742b3cdaa65ae    delivered                6735.0
#
#        order_freight_value  order_items_qty  order_sellers_qty  \
# 66418               224.08                8                  1
# 69811               140.44                1                  1
# 53594               137.60                5                  1
# 41833               114.88                4                  1
# 35123               194.31                1                  1
#
#          order_purchase_timestamp            order_aproved_at  \
# 66418  2017-09-29 15:24:52.000000  2017-10-02 15:28:20.628335
# ...

# %% [markdown]
# ##Look for correlations

# %%
dfs = {
    'classified': df_classified,
    'location': df_geolocation,
    'payments': df_payments,
    'product_measures': df_product_measures,
    'public_data': df_public_dataset,
    'customers': df_public_dataset_customers,
    'sellers': df_sellers,
    'translation': df_translation
}

for name, df in dfs.items():
    numeric_df = df.select_dtypes(include=[float, int])
    print(f"\nCorrelation matrix for {name}:")
    print(numeric_df.corr())
# Out:
# Correlation matrix for classified:
#                             Unnamed: 0        id  order_products_value  \
# Unnamed: 0                    1.000000  1.000000              0.010331
# id                            1.000000  1.000000              0.010331
# order_products_value          0.010331  0.010331              1.000000
# order_freight_value          -0.015461 -0.015461              0.391851
# order_items_qty               0.009656  0.009656              0.109220
# order_sellers_qty            -0.018544 -0.018544             -0.075359
# customer_zip_code_prefix     -0.005227 -0.005227              0.064933
# product_name_lenght           0.005655  0.005655              0.018941
# product_description_lenght   -0.010315 -0.010315              0.204682
# product_photos_qty            0.020243  0.020243              0.052394
# review_score                 -0.006939 -0.006939             -0.037968
# review_comment_title               NaN       NaN                   NaN
# ...

# %% [markdown]
# ##HeatMap

# %%
import matplotlib.pyplot as plt
import seaborn as sns

for name, df in dfs.items():
    numeric_df = df.select_dtypes(include=[float, int])
    corr = numeric_df.corr()

    if corr.empty:
        print(f"\nSkipping {name} because correlation matrix is empty or no numeric data.")
        continue

    plt.figure(figsize=(10,8))
    sns.heatmap(corr, annot=True, fmt=".2f", cmap='coolwarm', linewidths=0.5)
    plt.title(f'Correlation Matrix Heatmap for {name}')
    plt.show()
# Out:
# Skipping customers because correlation matrix is empty or no numeric data.
# Skipping translation because correlation matrix is empty or no numeric data.

# %% [markdown]
# ##Outliers

# %%
import matplotlib.pyplot as plt
import seaborn as sns

for name, df in dfs.items():
    numeric_df = df.select_dtypes(include=[float, int])
    corr = numeric_df.corr()

    if corr.empty:
        print(f"\nSkipping {name} because correlation matrix is empty or no numeric data.")
        continue

    # Plot boxplot for numeric columns to detect outliers
    plt.figure(figsize=(12, 6))
    numeric_df.boxplot()
    plt.title(f'Boxplot for Numeric Columns of {name}')
    plt.xticks(rotation=45)
    plt.show()
# Out:
# Skipping customers because correlation matrix is empty or no numeric data.
# Skipping translation because correlation matrix is empty or no numeric data.
